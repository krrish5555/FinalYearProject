# %% [markdown]
# ## Modifying Notebook display

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    .container#notebook-container    { width: 95%;}
    div#menubar-container     { width: 95%; }
    div#maintoolbar-container { width: 95%; }
</style>
<script>
    document.getElementById("notebook-container").style.margin = "auto";
</script>
"""))
# Out:
# <style>
#     .container#notebook-container    { width: 95%;}
#     div#menubar-container     { width: 95%; }
#     div#maintoolbar-container { width: 95%; }
# </style>
# <script>
#     document.getElementById("notebook-container").style.margin = "auto";
# </script>

# %% [markdown]
# ## For running the notebook as Google Colab Instance

# %% [markdown]
# #mounting the google drive for accessing other necessary files
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# #Checking the available files in the "Colab Notebooks" folder of the google drive
# !ls /content/gdrive/My\ Drive/Colab\ Notebooks
#
# import sys
#
# #changing the current working directory to "Colab Notebooks" folder in the google drive
# sys.path.append('/content/gdrive/My Drive/Colab Notebooks')

# %% [markdown]
# ## For running the notebook as Kaggle Kernel

# %% [markdown]
# change directory to the dataset where our custom scripts are uploaded
#
# > ``os.chdir("/kaggle/input/handwritten-digit-recognition")``
#
# ***handwritten-digit-recognition*** is simply a folder name. It can vary based on the dataset you create in kaggle while uploading the python scripts.
#
#
# load custom module or files or dataset
#
# > ``from  dataset import load_dataset, train_dev_split, prep_dataset`` <br>
# > ```from dataset import visualize_data_distribution, visualize_dataset```
#
#
# reset our working directory
#
# > ```os.chdir("/kaggle/working/")```
#
# **NOTE:** The ***input directory*** is Read-Only. So, we must switch back to the ***working directory*** for performing any other operation that requires write access. Make sure this note book runs as a part of the dataset you create as said above because all the custom modules are uploaded there.

# %% [markdown]
# ## Integrating Weights and Biases
# for remote training evaluation

# %%
# !wandb login 79ece8e045783ede11c19a366a80babadfc8ef34
# Out:
# wandb: Currently logged in as: befrenz (use `wandb login --relogin` to force relogin)

# %%
import wandb
run = wandb.init(project="handwritten-digit-recognition")
# Out:
# wandb: Currently logged in as: befrenz (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.1
# wandb: Run data is saved locally in wandb/run-20200918_202912-175ytdd6
# wandb: Syncing run trim-sea-13
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/befrenz/handwritten-digit-recognition" target="_blank">https://app.wandb.ai/befrenz/handwritten-digit-recognition</a><br/>
#                 Run page: <a href="https://app.wandb.ai/befrenz/handwritten-digit-recognition/runs/175ytdd6" target="_blank">https://app.wandb.ai/befrenz/handwritten-digit-recognition/runs/175ytdd6</a><br/>

# %% [markdown]
# ## Importing Dependencies

# %%
import time    #for calculating time
import os
import gc
#core packages
import numpy as np
import matplotlib.pyplot as plt

# os.chdir("/kaggle/input/handwritten-digit-recognition")

#custom module
from dataset import load_dataset, train_dev_split, prep_dataset
from dataset import visualize_data_distribution, visualize_dataset

from ModelUtils import relu, relu_grad, softmax
from ModelUtils import rand_mini_batches, convert_time
from ModelUtils import confusion_matrix, plot_confusion_matrix, model_metrics, metric_summary
from ModelUtils import visualize_training_results, visualize_prediction, visualize_mislabelled_images
from ModelUtils import save_model, load_model

from dataAugmentation import data_generator,load_augmented_data

from ffnn import *


# np.random.seed(1)
# %matplotlib inline

# %% [markdown]
# ## Dataset Preparation

# %% [markdown]
# ### Loading Dataset

# %%
dataset_size_in_per = 100

train_x_orig, train_y_orig, test_x_orig, test_y_orig = load_dataset(dataset = "mnist", size_in_per = dataset_size_in_per)

print("Sample Size : %d%%\n"%(dataset_size_in_per))
print("Data\t\t\t","Datatype\t\t","Dataset Size")
print("=================================================================")
print("Training Set Images:\t" + str(type(train_x_orig))+"\t",str(train_x_orig.shape))
print("Training Set Labels:\t" + str(type(train_y_orig))+"\t",str(train_y_orig.shape))
print("Test Set Images:\t" + str(type(test_x_orig))+"\t",str(test_x_orig.shape))
print("Test Set Labels:\t" + str(type(test_y_orig))+"\t",str(test_y_orig.shape))
print("=================================================================")
# Out:
# Sample Size : 100%
#
# Data			 Datatype		 Dataset Size
# =================================================================
# Training Set Images:	<class 'numpy.ndarray'>	 (60000, 28, 28)
# Training Set Labels:	<class 'numpy.ndarray'>	 (60000, 1)
# Test Set Images:	<class 'numpy.ndarray'>	 (10000, 28, 28)
# Test Set Labels:	<class 'numpy.ndarray'>	 (10000, 1)
# =================================================================

# %% [markdown]
# ### Train-Dev set Split

# %%
train_x_split, train_y_split, dev_x_split, dev_y_split = train_dev_split(train_x_orig, train_y_orig)

print("Data\t\t\t\t","Datatype\t\t","Shape")
print("========================================================================")
print("Training Set Images:\t\t" + str(type(train_x_split))+"\t",str(train_x_split.shape))
print("Training Set Labels:\t\t" + str(type(train_y_split))+"\t",str(train_y_split.shape))
print("Development Set Images:\t\t" + str(type(dev_x_split))+"\t",str(dev_x_split.shape))
print("Development Set Labels:\t\t" + str(type(dev_y_split))+"\t",str(dev_y_split.shape))
print("========================================================================")
# Out:
# Data				 Datatype		 Shape
# ========================================================================
# Training Set Images:		<class 'numpy.ndarray'>	 (50000, 28, 28)
# Training Set Labels:		<class 'numpy.ndarray'>	 (50000, 1)
# Development Set Images:		<class 'numpy.ndarray'>	 (10000, 28, 28)
# Development Set Labels:		<class 'numpy.ndarray'>	 (10000, 1)
# ========================================================================

# %% [markdown]
# ### Visualizing Data Distribution

# %%
visualize_data_distribution(train_y_split, dataset_type = "training")
visualize_data_distribution(dev_y_split,  dataset_type = "dev")
visualize_data_distribution(test_y_orig,  dataset_type = "test")

# %% [markdown]
# ### Visualizing Dataset

# %%
visualize_dataset(train_x_split, train_y_split, dataset = "mnist", dataset_type = "training")
visualize_dataset(dev_x_split, dev_y_split, dataset = "mnist", dataset_type = "dev")
visualize_dataset(test_x_orig, test_y_orig, dataset = "mnist", dataset_type="test")

# %% [markdown]
# ### Preparing Dataset

# %% [markdown]
# The preprocess training set will only be used later during prediction. The splitted training set will be directly fed to the model and it is preprocessed in the fly during the augmentation process.

# %%
train_x_norm, train_y_encoded = prep_dataset(train_x_split, train_y_split, num_class = 10)
dev_x_norm, dev_y_encoded= prep_dataset(dev_x_split, dev_y_split, num_class = 10)
test_x_norm, test_y_encoded = prep_dataset(test_x_orig, test_y_orig, num_class = 10)

print("Data\t\t\t","Before Processing\t","After Processing")
print("=================================================================")
print("Training Set Images:\t" + str(train_x_split.shape)+"\t\t"+ str(train_x_norm.shape))
print("Training Set Labels:\t" + str(train_y_split.shape)+"\t\t"+ str(train_y_encoded.shape))
print("Dev Set Images:\t\t" + str(dev_x_split.shape)+"\t\t"+ str(dev_x_norm.shape))
print("Dev Set Labels:\t\t" + str(dev_y_split.shape)+"\t\t"+ str(dev_y_encoded.shape))
print("Test Set Images:\t" + str(test_x_orig.shape)+"\t\t"+ str(test_x_norm.shape))
print("Test Set Labels:\t" + str(test_y_orig.shape)+"\t\t"+ str(test_y_encoded.shape))
print("=================================================================")
# Out:
# Data			 Before Processing	 After Processing
# =================================================================
# Training Set Images:	(50000, 28, 28)		(784, 50000)
# Training Set Labels:	(50000, 1)		(10, 50000)
# Dev Set Images:		(10000, 28, 28)		(784, 10000)
# Dev Set Labels:		(10000, 1)		(10, 10000)
# Test Set Images:	(10000, 28, 28)		(784, 10000)
# Test Set Labels:	(10000, 1)		(10, 10000)
# =================================================================

# %% [markdown]
# ### Train Model

# %%
# Final Model Training
def train(training_data, validation_data , layers_dim, hyperParams, initialization = "random", optimizer = 'bgd',regularizer = None, verbose = 3, patience = None, step_decay = None):
    # unpacking the hyperparameters
    learning_rate = hyperParams['learning_rate']
    num_epoch = hyperParams['num_epoch']
    b1 = hyperParams['beta1']
    b2 = hyperParams['beta2']
    ep = hyperParams['epsilon']
    lambd = hyperParams['lambda']
    keep_probs = hyperParams['keep_probs']
    
    # unpacking the data
    X_train, Y_train = training_data
    X_dev,Y_dev = validation_data

    # setting up necessary variables for early stopping
    if patience != None and patience !=0:
        # configuring path to save the intermediate best parameters
        path = "temp/" 
        if not os.path.exists(path):
            os.makedirs(path) 
        filename = "best_param_intermediate"

        early_stop_count = 0 # count variable for counting consucative the epochs without progress
        max_val_acc = 0 # for keeping track of maximum validation accuracy
    
    #initializing the training variables
    seed = 1
    m = Y_train.shape[1]
    train_accs = []  # for keeping track of training accuracy
    val_accs = []     # for keeping track of Validation accuracy
    train_losses = []  # for keeping track of training loss
    val_losses = []     # for keeping track of Validation loss
    
    #selecting the minibatch size for each optimizer
    if optimizer == 'sgd':
        mini_batch_size = 1
    elif optimizer == 'bgd':
        mini_batch_size = m
    elif optimizer == 'mgd' or optimizer == 'adam':
        mini_batch_size = hyperParams['mini_batch_size']
    else:
        raise ValueError("Optimizer value out of scope")
        
    #initializing the model parameters
    parameters = init_parameters(layers_dim, initialization)
    
    #initializing adam parameters, used only when optimizer = 'adam'
    t = 0
    v,s = initialize_adam(parameters)
    
    train_tic = time.time() # for calculating entire training time
    print("Training The Model...")
    
    #Gradient Descent begins
    for i in range(num_epoch):
        seed += 1
        time_trained = 0 # for computing training time of each epoch
        batch_times = [] # for accumulating the training time of each batch
        accs = [] # for tracking batch training accuracy
        losses = [] # for tracking batch training loss
        
        #learning rate scheduling
        if step_decay!= None and step_decay!= 0:
            if i%step_decay == 0:
                decay_rate = learning_rate / ((i+1)/num_epoch)
                learning_rate = learning_rate_scledule(learning_rate, i, decay_rate)
                if learning_rate <= 0.0001: learning_rate = 0.0001 
        
           
        if verbose > 0:
            if step_decay!= None and step_decay!= 0:
                print("\nEpoch %d/%d: learning rate - %.6f"%(i+1,num_epoch,learning_rate))
            else:
                print("\nEpoch %d/%d"%(i+1,num_epoch))
        
        #augmenting the dataset online
        data_generator(X_train, Y_train, batch_size = 2048, aug_count = 1, pre_process_data = True)
        aug_images,aug_labels = load_augmented_data()
        
        #generating minibatches of the augmented dataset
        minibatches = rand_mini_batches(aug_images, aug_labels, mini_batch_size, seed)
        total_minibatches = len(minibatches)
        
        del aug_images,aug_labels
        
        for ind, minibatch in enumerate(minibatches):
            batch_tic = time.time() # for calculating time of an epoch cycle
            
            #retriving minibatch of X and Y from training set
            (minibatch_X, minibatch_Y) = minibatch
            
            #forward Propagation
            AL, caches, dropout_masks = forward_prop(minibatch_X, parameters, keep_probs = keep_probs, regularizer = regularizer)
            
            #Computing cross entropy cost
            cross_entropy_cost = softmax_cross_entropy_cost(AL, minibatch_Y, caches, lambd = lambd, regularizer = regularizer, from_logits = True) #accumulating the batch costs
            
            #Backward Propagation
            grads = backward_prop(AL, minibatch_Y, caches, dropout_masks = dropout_masks, keep_probs = keep_probs, lambd = lambd, regularizer = regularizer)
                
            #Updating parameters
            t += 1
            parameters, v, s = update_parameters(parameters, grads, learning_rate, optimizer = optimizer, beta1 = b1, beta2 = b2,  epsilon = ep, v = v, s = s, t = t)
            
            # Calculating training time for each batch 
            batch_times.append(time.time() - batch_tic)
            time_trained = np.sum(batch_times)
            
            #calculating training progress
            per = ((ind+1) / total_minibatches) * 100
            inc = int(per // 10) * 2
            
            #calculating accuracy and loss of the training batch
            acc,loss = evaluate(minibatch_X, minibatch_Y, parameters)
            accs.append(acc)
            losses.append(loss)
            
            
            #Verbosity 0: Silent mode
            #Verbosity 1: Epoch mode
            #Verbosity 2: Progress bar mode
            #Verbosity 3 or greater: Metric mode
                
            if verbose == 2:
                print ("%d/%d [%s>%s %.0f%%] - %.2fs"%(ind+1, total_minibatches, '=' * inc,'.'*(20-inc), per, time_trained),end='\r')
            elif verbose > 2:
                print ("%d/%d [%s>%s %.0f%%] - %.2fs | loss: %.4f | acc: %.4f"%(ind+1, total_minibatches, '=' * inc,'.'*(20-inc), per, time_trained, np.mean(losses), np.mean(accs)),end='\r')
            
            del caches,minibatch_X, minibatch_Y,minibatch,grads #clearing caches
        #----------------------------------------------batch ends-------------------------------------------

        #accumulating the acc and loss of the last iteration of each epoch
        train_accs.append(np.mean(accs))
        train_losses.append(np.mean(losses))
                
        #evaluating the model using validation accuracy and loss
        val_acc, val_loss= evaluate(X_dev, Y_dev, parameters)  
        val_accs.append(val_acc)
        val_losses.append(val_loss)
        
        #logging the metrices using wandb
        wandb.log({"Epoch":i+1,
                   "Training Acc":np.mean(accs),
                   "Training Loss":np.mean(losses),
                   "Validation Acc":val_acc,
                   "Validation Loss":val_loss})
       
        time_per_batch = int(np.mean(batch_times)*1000)

        if verbose == 2:
            print ("%d/%d [%s 100%%] - %.2fs %dms/step"%(total_minibatches, total_minibatches, '=' * 20, time_trained, time_per_batch ),end='\r')
        elif verbose > 2:
            print ("%d/%d [%s 100%%] - %.2fs %dms/step | loss: %.4f | acc: %.4f | val_loss: %.4f | val_acc: %.4f"%(total_minibatches, total_minibatches, '=' * 20, time_trained, time_per_batch, np.mean(losses), np.mean(accs), val_loss, val_acc),end='\r')
                
        #early stopping implementation
        if patience != None and patience !=0:
            #getting the best val accuracy
            if val_acc >= max_val_acc:
                max_val_acc = val_acc
                #logging best val acc as well
                wandb.run.summary["best_val_accuracy"] = max_val_acc
                print("\nImprovement in validation accuracy found. Saving the corresponding parameters...")
                save_model(path+filename, parameters)
                early_stop_count = 0
            else:
                early_stop_count += 1
            
            if early_stop_count == patience:
                print("\n\nSince the Val Acc didn't increase for last %d epochs, Training is halted returning the best parameters obtained."%patience)
                break;
        
        del minibatches
        gc.collect()
                
    #-------------------------------------------Gradient Descent ends-----------------------------------------------
    
    hrs, mins, secs , ms = convert_time((time.time() - train_tic)*1000)
    print("\n\nTotal Training Time = %dhr %dmins %dsecs %.2fms"%(hrs, mins, secs, ms))
    
    #loading the best parameters
    if patience != None and patience !=0:
        parameters = load_model(path+filename)
        os.remove(path + filename) #removing temporary file
    
    #saving weights to wandb
    np.save(path+"weights",parameters)
    wandb.save(path+"weights.npy")
    
    history = {"parameters":parameters,
               "accuracy": train_accs,
               "loss":train_losses ,
               "val_accuracy":val_accs,
               "val_loss":val_losses
            }
    return history

# %% [markdown]
# #### Running Model

# %%
layers_dim = init_layers(784, 10,hidden_layers = [2900])
training_data = (train_x_split, train_y_split)
validation_data = (dev_x_norm, dev_y_encoded)
hyperParams = init_hyperParams(alpha = 0.00163, num_epoch = 100, minibatch_size = 262,lambd = 0.7,keep_probs = [0.8])

history = train(training_data, validation_data ,layers_dim, hyperParams, initialization = "he", optimizer = 'adam',regularizer = "dropout", patience = 20)
# Out:
# Training The Model...
#
# Epoch 1/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 86.87s 113ms/step | loss: 0.3269 | acc: 0.9040 | val_loss: 0.0878 | val_acc: 0.9731
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 2/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 93.25s 122ms/step | loss: 0.1347 | acc: 0.9620 | val_loss: 0.0718 | val_acc: 0.9766
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 3/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 84.41s 110ms/step | loss: 0.0909 | acc: 0.9747 | val_loss: 0.0755 | val_acc: 0.9782
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 4/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 83.47s 109ms/step | loss: 0.0670 | acc: 0.9815 | val_loss: 0.0722 | val_acc: 0.9806
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 5/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 92.36s 120ms/step | loss: 0.0509 | acc: 0.9862 | val_loss: 0.0786 | val_acc: 0.9797
# Epoch 6/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 99.87s 130ms/step | loss: 0.0411 | acc: 0.9888 | val_loss: 0.0854 | val_acc: 0.9803
# Epoch 7/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 92.76s 121ms/step | loss: 0.0337 | acc: 0.9908 | val_loss: 0.0668 | val_acc: 0.9843
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 8/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 91.84s 120ms/step | loss: 0.0286 | acc: 0.9924 | val_loss: 0.0760 | val_acc: 0.9834
# Epoch 9/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 89.40s 117ms/step | loss: 0.0260 | acc: 0.9929 | val_loss: 0.0776 | val_acc: 0.9843
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 10/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 92.32s 120ms/step | loss: 0.0221 | acc: 0.9940 | val_loss: 0.0854 | val_acc: 0.9831
# Epoch 11/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 93.37s 122ms/step | loss: 0.0195 | acc: 0.9947 | val_loss: 0.0859 | val_acc: 0.9837
# Epoch 12/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 93.07s 121ms/step | loss: 0.0188 | acc: 0.9950 | val_loss: 0.0833 | val_acc: 0.9837
# Epoch 13/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 90.81s 118ms/step | loss: 0.0173 | acc: 0.9954 | val_loss: 0.0923 | val_acc: 0.9834
# Epoch 14/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 81.82s 107ms/step | loss: 0.0158 | acc: 0.9956 | val_loss: 0.0916 | val_acc: 0.9841
# Epoch 15/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 87.24s 114ms/step | loss: 0.0151 | acc: 0.9959 | val_loss: 0.0960 | val_acc: 0.9847
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 16/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 83.20s 108ms/step | loss: 0.0134 | acc: 0.9964 | val_loss: 0.0918 | val_acc: 0.9855
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 17/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 89.10s 116ms/step | loss: 0.0128 | acc: 0.9964 | val_loss: 0.0881 | val_acc: 0.9846
# Epoch 18/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 86.52s 113ms/step | loss: 0.0124 | acc: 0.9965 | val_loss: 0.1027 | val_acc: 0.9836
# Epoch 19/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 89.07s 116ms/step | loss: 0.0118 | acc: 0.9968 | val_loss: 0.1035 | val_acc: 0.9852
# Epoch 20/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 85.84s 112ms/step | loss: 0.0117 | acc: 0.9968 | val_loss: 0.1032 | val_acc: 0.9843
# Epoch 21/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 90.06s 117ms/step | loss: 0.0111 | acc: 0.9969 | val_loss: 0.1111 | val_acc: 0.9833
# Epoch 22/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 82.71s 108ms/step | loss: 0.0096 | acc: 0.9974 | val_loss: 0.1109 | val_acc: 0.9835
# Epoch 23/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 85.69s 112ms/step | loss: 0.0100 | acc: 0.9974 | val_loss: 0.1238 | val_acc: 0.9841
# Epoch 24/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 96.01s 125ms/step | loss: 0.0100 | acc: 0.9972 | val_loss: 0.1206 | val_acc: 0.9831
# Epoch 25/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 90.05s 117ms/step | loss: 0.0094 | acc: 0.9975 | val_loss: 0.1275 | val_acc: 0.9851
# Epoch 26/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 82.92s 108ms/step | loss: 0.0091 | acc: 0.9975 | val_loss: 0.1093 | val_acc: 0.9852
# Epoch 27/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 81.84s 107ms/step | loss: 0.0086 | acc: 0.9976 | val_loss: 0.1249 | val_acc: 0.9847
# Epoch 28/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 87.95s 115ms/step | loss: 0.0089 | acc: 0.9975 | val_loss: 0.1176 | val_acc: 0.9857
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 29/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 93.52s 122ms/step | loss: 0.0085 | acc: 0.9978 | val_loss: 0.1218 | val_acc: 0.9850
# Epoch 30/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.60s 115ms/step | loss: 0.0083 | acc: 0.9978 | val_loss: 0.1228 | val_acc: 0.9856
# Epoch 31/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 86.36s 113ms/step | loss: 0.0080 | acc: 0.9978 | val_loss: 0.1200 | val_acc: 0.9862
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 32/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 89.06s 116ms/step | loss: 0.0077 | acc: 0.9979 | val_loss: 0.1391 | val_acc: 0.9852
# Epoch 33/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.41s 115ms/step | loss: 0.0076 | acc: 0.9979 | val_loss: 0.1246 | val_acc: 0.9866
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 34/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 85.61s 112ms/step | loss: 0.0075 | acc: 0.9979 | val_loss: 0.1424 | val_acc: 0.9857
# Epoch 35/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 80.42s 105ms/step | loss: 0.0068 | acc: 0.9982 | val_loss: 0.1365 | val_acc: 0.9862
# Epoch 36/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 83.37s 109ms/step | loss: 0.0070 | acc: 0.9981 | val_loss: 0.1371 | val_acc: 0.9857
# Epoch 37/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 90.96s 119ms/step | loss: 0.0074 | acc: 0.9980 | val_loss: 0.1470 | val_acc: 0.9862
# Epoch 38/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 86.56s 113ms/step | loss: 0.0070 | acc: 0.9981 | val_loss: 0.1526 | val_acc: 0.9858
# Epoch 39/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 91.60s 119ms/step | loss: 0.0065 | acc: 0.9982 | val_loss: 0.1514 | val_acc: 0.9856
# Epoch 40/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.32s 115ms/step | loss: 0.0066 | acc: 0.9982 | val_loss: 0.1615 | val_acc: 0.9851
# Epoch 41/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.43s 115ms/step | loss: 0.0071 | acc: 0.9979 | val_loss: 0.1607 | val_acc: 0.9853
# Epoch 42/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.14s 115ms/step | loss: 0.0060 | acc: 0.9984 | val_loss: 0.1571 | val_acc: 0.9858
# Epoch 43/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 92.00s 120ms/step | loss: 0.0059 | acc: 0.9984 | val_loss: 0.1580 | val_acc: 0.9863
# Epoch 44/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 82.00s 107ms/step | loss: 0.0063 | acc: 0.9982 | val_loss: 0.1578 | val_acc: 0.9872
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 45/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 80.46s 105ms/step | loss: 0.0055 | acc: 0.9984 | val_loss: 0.1764 | val_acc: 0.9860
# Epoch 46/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 82.73s 108ms/step | loss: 0.0061 | acc: 0.9984 | val_loss: 0.1597 | val_acc: 0.9864
# Epoch 47/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 79.80s 104ms/step | loss: 0.0061 | acc: 0.9984 | val_loss: 0.1912 | val_acc: 0.9855
# Epoch 48/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 87.42s 114ms/step | loss: 0.0062 | acc: 0.9982 | val_loss: 0.1699 | val_acc: 0.9870
# Epoch 49/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 86.50s 113ms/step | loss: 0.0060 | acc: 0.9983 | val_loss: 0.1803 | val_acc: 0.9863
# Epoch 50/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 84.08s 110ms/step | loss: 0.0054 | acc: 0.9986 | val_loss: 0.1776 | val_acc: 0.9862
# Epoch 51/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 80.47s 105ms/step | loss: 0.0056 | acc: 0.9984 | val_loss: 0.1773 | val_acc: 0.9875
# Improvement in validation accuracy found. Saving the corresponding parameters...
#
# Epoch 52/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 83.24s 108ms/step | loss: 0.0053 | acc: 0.9985 | val_loss: 0.1723 | val_acc: 0.9863
# Epoch 53/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 80.92s 105ms/step | loss: 0.0058 | acc: 0.9984 | val_loss: 0.1734 | val_acc: 0.9868
# Epoch 54/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 79.49s 104ms/step | loss: 0.0053 | acc: 0.9986 | val_loss: 0.1903 | val_acc: 0.9864
# Epoch 55/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 84.98s 111ms/step | loss: 0.0051 | acc: 0.9985 | val_loss: 0.1627 | val_acc: 0.9863
# Epoch 56/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.97s 116ms/step | loss: 0.0050 | acc: 0.9985 | val_loss: 0.2141 | val_acc: 0.9843
# Epoch 57/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.19s 115ms/step | loss: 0.0050 | acc: 0.9988 | val_loss: 0.1867 | val_acc: 0.9863
# Epoch 58/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 86.67s 113ms/step | loss: 0.0047 | acc: 0.9987 | val_loss: 0.1893 | val_acc: 0.9857
# Epoch 59/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.24s 115ms/step | loss: 0.0049 | acc: 0.9986 | val_loss: 0.2082 | val_acc: 0.9854
# Epoch 60/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.60s 115ms/step | loss: 0.0047 | acc: 0.9986 | val_loss: 0.2020 | val_acc: 0.9863
# Epoch 61/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 96.38s 126ms/step | loss: 0.0051 | acc: 0.9987 | val_loss: 0.2194 | val_acc: 0.9853
# Epoch 62/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 85.03s 111ms/step | loss: 0.0047 | acc: 0.9986 | val_loss: 0.1965 | val_acc: 0.9871
# Epoch 63/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 89.76s 117ms/step | loss: 0.0051 | acc: 0.9987 | val_loss: 0.2206 | val_acc: 0.9847
# Epoch 64/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 87.68s 114ms/step | loss: 0.0046 | acc: 0.9988 | val_loss: 0.2031 | val_acc: 0.9872
# Epoch 65/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.00s 115ms/step | loss: 0.0045 | acc: 0.9988 | val_loss: 0.2131 | val_acc: 0.9863
# Epoch 66/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 90.94s 119ms/step | loss: 0.0043 | acc: 0.9988 | val_loss: 0.2265 | val_acc: 0.9850
# Epoch 67/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 88.70s 116ms/step | loss: 0.0050 | acc: 0.9987 | val_loss: 0.2174 | val_acc: 0.9869
# Epoch 68/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 89.42s 117ms/step | loss: 0.0054 | acc: 0.9986 | val_loss: 0.2321 | val_acc: 0.9858
# Epoch 69/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 90.33s 118ms/step | loss: 0.0046 | acc: 0.9988 | val_loss: 0.1939 | val_acc: 0.9869
# Epoch 70/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 92.30s 120ms/step | loss: 0.0043 | acc: 0.9988 | val_loss: 0.2109 | val_acc: 0.9862
# Epoch 71/100
# Generating 200K Augmented images...
# 764/764 [==================== 100%] - 90.60s 118ms/step | loss: 0.0042 | acc: 0.9988 | val_loss: 0.2302 | val_acc: 0.9867
#
# Since the Val Acc didn't increase for last 20 epochs, Training is halted returning the best parameters obtained.
#
#
# Total Training Time = 2hr 39mins 40secs 789.41ms

# %%
params = history["parameters"]
train_acc = history["accuracy"]
train_loss = history["loss"]
val_acc = history["val_accuracy"]
val_loss = history["val_loss"]
epochs = len(val_acc)


visualize_training_results(train_acc, val_acc, train_loss, val_loss)

# %%
print("\n Epochs\t | Train Acc\t | Train Loss\t | Val Acc\t | Val Loss")
print("--------------------------------------------------------------------")
for i in range(epochs):
    print(" %d\t | %f\t | %f\t | %f\t | %f"%(i+1,train_acc[i] ,train_loss[i],val_acc[i] ,val_loss[i] ))
# Out:
#  Epochs	 | Train Acc	 | Train Loss	 | Val Acc	 | Val Loss
# --------------------------------------------------------------------
#  1	 | 0.903972	 | 0.326950	 | 0.973100	 | 0.087756
#  2	 | 0.961952	 | 0.134672	 | 0.976600	 | 0.071844
#  3	 | 0.974679	 | 0.090884	 | 0.978200	 | 0.075533
#  4	 | 0.981487	 | 0.067041	 | 0.980600	 | 0.072241
#  5	 | 0.986218	 | 0.050938	 | 0.979700	 | 0.078627
#  6	 | 0.988820	 | 0.041110	 | 0.980300	 | 0.085382
#  7	 | 0.990833	 | 0.033659	 | 0.984300	 | 0.066836
#  8	 | 0.992427	 | 0.028624	 | 0.983400	 | 0.075983
#  9	 | 0.992892	 | 0.025951	 | 0.984300	 | 0.077588
#  10	 | 0.993965	 | 0.022126	 | 0.983100	 | 0.085447
#  11	 | 0.994719	 | 0.019533	 | 0.983700	 | 0.085882
#  12	 | 0.994959	 | 0.018794	 | 0.983700	 | 0.083347
#  13	 | 0.995444	 | 0.017252	 | 0.983400	 | 0.092329
#  14	 | 0.995554	 | 0.015781	 | 0.984100	 | 0.091605
#  15	 | 0.995900	 | 0.015067	 | 0.984700	 | 0.095985
#  16	 | 0.996398	 | 0.013399	 | 0.985500	 | 0.091781
#  17	 | 0.996438	 | 0.012822	 | 0.984600	 | 0.088135
#  18	 | 0.996513	 | 0.012372	 | 0.983600	 | 0.102722
#  19	 | 0.996798	 | 0.011805	 | 0.985200	 | 0.103480
#  20	 | 0.996754	 | 0.011742	 | 0.984300	 | 0.103222
#  21	 | 0.996903	 | 0.011131	 | 0.983300	 | 0.111117
#  22	 | 0.997392	 | 0.009561	 | 0.983500	 | 0.110949
#  23	 | 0.997447	 | 0.009980	 | 0.984100	 | 0.123799
#  24	 | 0.997212	 | 0.009993	 | 0.983100	 | 0.120574
#  25	 | 0.997452	 | 0.009395	 | 0.985100	 | 0.127524
#  26	 | 0.997512	 | 0.009109	 | 0.985200	 | 0.109309
#  27	 | 0.997637	 | 0.008569	 | 0.984700	 | 0.124937
#  28	 | 0.997548	 | 0.008863	 | 0.985700	 | 0.117649
#  29	 | 0.997752	 | 0.008469	 | 0.985000	 | 0.121782
#  30	 | 0.997812	 | 0.008252	 | 0.985600	 | 0.122785
#  31	 | 0.997792	 | 0.007952	 | 0.986200	 | 0.120025
#  32	 | 0.997872	 | 0.007654	 | 0.985200	 | 0.139089
#  33	 | 0.997872	 | 0.007583	 | 0.986600	 | 0.124615
#  34	 | 0.997882	 | 0.007450	 | 0.985700	 | 0.142353
#  35	 | 0.998192	 | 0.006829	 | 0.986200	 | 0.136454
#  36	 | 0.998052	 | 0.006998	 | 0.985700	 | 0.137113
#  37	 | 0.998002	 | 0.007395	 | 0.986200	 | 0.146994
#  38	 | 0.998087	 | 0.006951	 | 0.985800	 | 0.152582
#  39	 | 0.998198	 | 0.006493	 | 0.985600	 | 0.151428
#  40	 | 0.998197	 | 0.006579	 | 0.985100	 | 0.161538
#  41	 | 0.997917	 | 0.007066	 | 0.985300	 | 0.160735
#  42	 | 0.998441	 | 0.005972	 | 0.985800	 | 0.157051
#  43	 | 0.998406	 | 0.005901	 | 0.986300	 | 0.157998
#  44	 | 0.998216	 | 0.006298	 | 0.987200	 | 0.157836
#  45	 | 0.998446	 | 0.005497	 | 0.986000	 | 0.176420
#  46	 | 0.998366	 | 0.006120	 | 0.986400	 | 0.159666
#  47	 | 0.998401	 | 0.006146	 | 0.985500	 | 0.191198
#  48	 | 0.998226	 | 0.006174	 | 0.987000	 | 0.169891
#  49	 | 0.998271	 | 0.006043	 | 0.986300	 | 0.180253
#  50	 | 0.998561	 | 0.005433	 | 0.986200	 | 0.177575
#  51	 | 0.998411	 | 0.005596	 | 0.987500	 | 0.177304
#  52	 | 0.998517	 | 0.005329	 | 0.986300	 | 0.172260
#  53	 | 0.998426	 | 0.005790	 | 0.986800	 | 0.173357
#  54	 | 0.998621	 | 0.005308	 | 0.986400	 | 0.190278
#  55	 | 0.998531	 | 0.005129	 | 0.986300	 | 0.162650
#  56	 | 0.998541	 | 0.004962	 | 0.984300	 | 0.214100
#  57	 | 0.998751	 | 0.005024	 | 0.986300	 | 0.186683
#  58	 | 0.998746	 | 0.004650	 | 0.985700	 | 0.189278
#  59	 | 0.998636	 | 0.004866	 | 0.985400	 | 0.208154
#  60	 | 0.998641	 | 0.004734	 | 0.986300	 | 0.201952
#  61	 | 0.998651	 | 0.005145	 | 0.985300	 | 0.219447
#  62	 | 0.998601	 | 0.004672	 | 0.987100	 | 0.196454
#  63	 | 0.998686	 | 0.005082	 | 0.984700	 | 0.220571
#  64	 | 0.998811	 | 0.004570	 | 0.987200	 | 0.203094
#  65	 | 0.998806	 | 0.004452	 | 0.986300	 | 0.213063
#  66	 | 0.998761	 | 0.004345	 | 0.985000	 | 0.226487
#  67	 | 0.998652	 | 0.004956	 | 0.986900	 | 0.217378
#  68	 | 0.998591	 | 0.005379	 | 0.985800	 | 0.232058
#  69	 | 0.998761	 | 0.004640	 | 0.986900	 | 0.193930
#  70	 | 0.998806	 | 0.004328	 | 0.986200	 | 0.210862
#  71	 | 0.998807	 | 0.004187	 | 0.986700	 | 0.230185

# %% [markdown]
# ### Evaluating test set

# %%
test_acc, test_loss = evaluate(test_x_norm,test_y_encoded,params)
#logging the metrices using wandb
wandb.log({"Test Acc":test_acc,
           "Test Loss":test_loss})

# %% [markdown]
# ### Prediction

# %%
prediction_train = predict(train_x_norm, params, second_guess = True)
prediction_dev = predict(dev_x_norm,params, second_guess = True)
prediction_test = predict(test_x_norm, params, second_guess = True)

# %% [markdown]
# ### Confusion Matrix

# %%
cm_train = confusion_matrix(train_y_split, prediction_train)
cm_dev = confusion_matrix(dev_y_split, prediction_dev)
cm_test = confusion_matrix(test_y_orig, prediction_test)

# %%
#plotting the confusion matrix   
plot_confusion_matrix(cm_train, dataset_type = "training")

# %%
plot_confusion_matrix(cm_dev, dataset_type = "dev")

# %%
plot_confusion_matrix(cm_test, dataset_type = "test")

# %%
metrics, macro_metrics, acc = model_metrics(cm_train)
metric_summary(metrics, macro_metrics, acc)

wandb.log({"Training Macro Precision":macro_metrics["Precision"],
           "Training Macro Recall":macro_metrics["Recall"],
           "Training Macro F1-Score":macro_metrics["F1-Score"]})
# Out:
# +===============+===============+===============+===============+
# | Label 	| Precision 	| Recall 	| F1 Score 	|
# +===============+===============+===============+===============+
# | 0 		|  1.00000 	|  0.99980 	|  0.99990 	|
# | 1 		|  0.99947 	|  0.99842 	|  0.99894 	|
# | 2 		|  0.99980 	|  0.99919 	|  0.99950 	|
# | 3 		|  0.99882 	|  0.99961 	|  0.99922 	|
# | 4 		|  0.99939 	|  0.99919 	|  0.99929 	|
# | 5 		|  0.99821 	|  0.99910 	|  0.99866 	|
# | 6 		|  0.99899 	|  0.99919 	|  0.99909 	|
# | 7 		|  0.99865 	|  0.99904 	|  0.99885 	|
# | 8 		|  0.99816 	|  0.99857 	|  0.99836 	|
# | 9 		|  0.99939 	|  0.99898 	|  0.99918 	|
# +===============+===============+===============+===============+
# | Macro Avg 	|  0.99909 	|  0.99911 	|  0.99910 	|
# +===============+===============+===============+===============+
#
#  Accuracy 		  0.99910

# %%
metrics, macro_metrics, acc = model_metrics(cm_dev)
metric_summary(metrics, macro_metrics, acc)

wandb.log({"Validation Macro Precision":macro_metrics["Precision"],
           "Validation Macro Recall":macro_metrics["Recall"],
           "Validation Macro F1-Score":macro_metrics["F1-Score"]})
# Out:
# +===============+===============+===============+===============+
# | Label 	| Precision 	| Recall 	| F1 Score 	|
# +===============+===============+===============+===============+
# | 0 		|  0.99690 	|  0.99381 	|  0.99535 	|
# | 1 		|  0.99057 	|  0.99432 	|  0.99245 	|
# | 2 		|  0.98795 	|  0.98795 	|  0.98795 	|
# | 3 		|  0.98462 	|  0.98842 	|  0.98651 	|
# | 4 		|  0.99341 	|  0.97730 	|  0.98529 	|
# | 5 		|  0.98841 	|  0.98015 	|  0.98426 	|
# | 6 		|  0.98993 	|  0.99797 	|  0.99393 	|
# | 7 		|  0.97874 	|  0.99157 	|  0.98512 	|
# | 8 		|  0.98747 	|  0.98337 	|  0.98542 	|
# | 9 		|  0.97893 	|  0.97893 	|  0.97893 	|
# +===============+===============+===============+===============+
# | Macro Avg 	|  0.98769 	|  0.98738 	|  0.98752 	|
# +===============+===============+===============+===============+
#
#  Accuracy 		  0.98750

# %%
metrics, macro_metrics, acc = model_metrics(cm_test)
metric_summary(metrics, macro_metrics, acc)

wandb.log({"Test Macro Precision":macro_metrics["Precision"],
           "Test Macro Recall":macro_metrics["Recall"],
           "Test Macro F1-Score":macro_metrics["F1-Score"]})
# Out:
# +===============+===============+===============+===============+
# | Label 	| Precision 	| Recall 	| F1 Score 	|
# +===============+===============+===============+===============+
# | 0 		|  0.99387 	|  0.99286 	|  0.99336 	|
# | 1 		|  0.99296 	|  0.99383 	|  0.99339 	|
# | 2 		|  0.98639 	|  0.98353 	|  0.98496 	|
# | 3 		|  0.98234 	|  0.99109 	|  0.98669 	|
# | 4 		|  0.99072 	|  0.97862 	|  0.98463 	|
# | 5 		|  0.98757 	|  0.97982 	|  0.98368 	|
# | 6 		|  0.98347 	|  0.99374 	|  0.98858 	|
# | 7 		|  0.97592 	|  0.98541 	|  0.98064 	|
# | 8 		|  0.98866 	|  0.98460 	|  0.98663 	|
# | 9 		|  0.98509 	|  0.98216 	|  0.98362 	|
# +===============+===============+===============+===============+
# | Macro Avg 	|  0.98670 	|  0.98656 	|  0.98662 	|
# +===============+===============+===============+===============+
#
#  Accuracy 		  0.98670

# %% [markdown]
# #### Visualizating  Prediction

# %%
visualize_prediction(train_x_split, train_y_split.T, prediction_train, dataset_type = "training")

# %%
visualize_prediction(dev_x_split, dev_y_split.T, prediction_dev, dataset_type = "dev")

# %%
visualize_prediction(test_x_orig, test_y_orig.T, prediction_test,dataset_type = "test")

# %% [markdown]
# #### Visualizing Mislabelled Images in all datasets

# %%
visualize_mislabelled_images(train_x_split, train_y_split.T,prediction_train,dataset_type = "training")
# Out:
# Total Mislabelled Images: 45

# %%
visualize_mislabelled_images(dev_x_split, dev_y_split.T, prediction_dev,dataset_type = "dev")
# Out:
# Total Mislabelled Images: 125

# %%
visualize_mislabelled_images(test_x_orig, test_y_orig.T, prediction_test,dataset_type = "test")
# Out:
# Total Mislabelled Images: 133

# %% [markdown]
# ### End logging

# %%
run.finish()
# Out:
# wandb: Waiting for W&B process to finish, PID 10336
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: wandb/run-20200918_202912-175ytdd6/logs/debug.log
# wandb: Find internal logs for this run at: wandb/run-20200918_202912-175ytdd6/logs/debug-internal.log
# wandb: Run summary:
# wandb:                        Epoch 71
# wandb:                 Training Acc 0.998807065894436
# wandb:                Training Loss 0.004186768485622331
# wandb:               Validation Acc 0.9867
# wandb:              Validation Loss 0.23018534963066578
# wandb:                        _step 74
# wandb:                     _runtime 12296
# wandb:                   _timestamp 1600452550
# wandb:            best_val_accuracy 0.9875
# wandb:                     Test Acc 0.9867
# wandb:                    Test Loss 0.14301176850373729
# wandb:     Training Macro Precision 0.9990880846453912
# wandb:        Training Macro Recall 0.9991082646169941
# wandb:      Training Macro F1-Score 0.9990980871263432
# wandb:   Validation Macro Precision 0.9876928869464656
# wandb:      Validation Macro Recall 0.9873788136949667
# wandb:    Validation Macro F1-Score 0.9875203423575425
# wandb:         Test Macro Precision 0.9866987048652746
# wandb:            Test Macro Recall 0.9865647338377629
# wandb:          Test Macro F1-Score 0.9866186780541742
# wandb: Run history:
# wandb:                        Epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:                 Training Acc ▁▅▇▇████████████████████████████████████
# wandb:                Training Loss █▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               Validation Acc ▁▃▅▅▆▆▆▆▇▇▆▆▆▆▇▇▇▇█▇▇▇▇▇█▇▇▇██▇▆▇▇█▇▇███
# wandb:              Validation Loss ▂▁▁▂▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▅▅▅▅▆▆▆▆▅▆▇▆▇▇█▇▇▆█
# wandb:                        _step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                     _runtime ▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆██
# wandb:                   _timestamp ▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆██
# wandb:                     Test Acc ▁
# wandb:                    Test Loss ▁
# wandb:     Training Macro Precision ▁
# wandb:        Training Macro Recall ▁
# wandb:      Training Macro F1-Score ▁
# wandb:   Validation Macro Precision ▁
# wandb:      Validation Macro Recall ▁
# wandb:    Validation Macro F1-Score ▁
# wandb:         Test Macro Precision ▁
# wandb:            Test Macro Recall ▁
# wandb:          Test Macro F1-Score ▁
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# wandb:
# wandb: Synced trim-sea-13: https://app.wandb.ai/befrenz/handwritten-digit-recognition/runs/175ytdd6

# %% [markdown]
# ### Predicting Real Time images

# %%
from PIL import Image

# %%
image_name = "8_1.jpg" 

fname = "Sample Images/" + image_name

image_data = np.asarray(Image.open(fname).convert('L').resize((28,28)))
if image_data[1,1] > 250: #if background is white, reversing the fore and background color to match training images
            image_data = 255 - image_data
def predict_real_time(image_data, second_guess = True):
    image_flattened = image_data.reshape(image_data.shape[0]*image_data.shape[1],-1)
    image_norm =(image_flattened/255.)

    prediction = predict(image_norm, params, second_guess = second_guess)
    
    return prediction
    
prediction = predict_real_time(image_data, second_guess = True)

first_lbl, first_prob = prediction["First Prediction"]
sec_lbl, sec_prob = prediction["Second Prediction"]

# plt.title("True Label: "+ str(label.squeeze()))
plt.xlabel("Prediction: %d | With Prob: %.4f \n2nd Guess: %d | With Prob: %.4f"%(first_lbl, first_prob, sec_lbl, sec_prob), fontsize = 14)
plt.imshow(image_data, interpolation ='nearest',cmap='gray')
plt.colorbar()

# %% [markdown]
# ## Saving and Loading model

# %%
path = "Saved Models/"
fname = "arch3_online_Augmented_model_200k_test_acc_"+str(acc)

print(fname)

model = {"Parameters": params,
         "Activations": ["relu","softmax"],
## Save the following info if needed
         "Hyper Parameters": hyperParams,
         "initialization":"he",
         "regularizer":"dropout",
         "optimizer":"adam"
        }
save_model(file_name = path+fname, model = model)

# %%
# loading model
path = "Saved Models/"

model = load_model(file_name =path+ "arch3_online_Augmented_model_200k_test_acc_0.986")

loaded_params = model["Parameters"]

# %%
L = len(loaded_params) // 2
print("Total Layers %d: "%L)
for l in range(L):
    print(loaded_params["W" + str(l+1)].shape[0])

# %% [markdown]
# ## To Do

# %% [markdown]
# - [ ] Optimize and refactor the code
# - [ ] Prepare the doc String
# - [x] add verbose: Integer. 0, 1, 2 or 3. Verbosity mode.
# - [ ] Batch norm
# - [ ] Maxout
# - [ ] Drop Connect
# - [x] Data Augmentation if possible

# %%
# !jupyter-nbconvert --to html 'Project Modules Evaluation with online data augmentation.ipynb' --output Experiments/wandb_integration.html
# Out:
# [NbConvertApp] Converting notebook Project Modules Evaluation with online data augmentation.ipynb to html
# [NbConvertApp] Writing 1066585 bytes to Experiments/wandb_integration.html
